# %%
import tensorflow as tf
import numpy as np
from nbutil import imshow_multi
import os
from PIL import Image
import urllib, cStringIO
import cv2

# %%
BATCH_SIZE = 64
MODE = 'EVAL' # TRAIN/EVAL

# %%
attr_file = '../data/celeba/list_attr_celeba.txt'
keys = None
attributes_by_image = {}
for i, line in enumerate(open(attr_file)):
    if i == 1:
        keys = line.split()
    elif i > 1:
        image = os.path.join('../data/celeba/img_align_celeba', line.split()[0])
        values = line.split()[1:]
        attributes_by_image[image] = {attr: val == '1' for attr, val in zip(keys, values)}

# %%
# print keys
image_names = attributes_by_image.keys()
attr_vector = np.zeros((len(attributes_by_image), len(keys)))
for i, image_name in enumerate(image_names):
    attrs = attributes_by_image[image_name]
    attr_vector[i] = [(1 if attrs[key] else 0) for key in keys]

from collections import defaultdict
key_value_pair_counts = defaultdict(int)
for attrs in attributes_by_image.itervalues():
    for pair in attrs.iteritems():
        key_value_pair_counts[pair] += 1
n_images = float(len(image_names))

rarity_vector = np.zeros((len(attributes_by_image), len(keys)))
for i, image_name in enumerate(image_names):
    attrs = attributes_by_image[image_name]
    rarity_vector[i] = [n_images / key_value_pair_counts[(key, attrs[key])] for key in keys]

# %%
# filename_queue = tf.train.string_input_producer(image_names, num_epochs=None)
# attr_queue = tf.train.input_producer(tf.constant(attr_vector), num_epochs=None)

def create_qs(train):
    filename_tensor = tf.convert_to_tensor(image_names, dtype=tf.string)
    attr_tensor = tf.convert_to_tensor(attr_vector, dtype=tf.float32)
    rarity_tensor = tf.convert_to_tensor(rarity_vector, dtype=tf.float32)
    filename_q, attr_q, rarity_q = tf.train.slice_input_producer([filename_tensor, attr_tensor, rarity_tensor], num_epochs=None, shuffle=True)

    # reader = tf.WholeFileReader()
    # filename, image_data = reader.read(filename_q)
    image_255 = tf.image.decode_jpeg(tf.read_file(filename_q))
    image = tf.reshape(tf.cast(image_255, tf.float32) / 255.0, [218, 178, 3]) # images are 178x218


    def resize_image(image):
        image = tf.random_crop(image, [192, 160, 3])
        return image
    #     image = tf.image.resize_bilinear(img_reshaped, [192, 160])
    #     return tf.reshape(image, [192, 160, 3])
    image = resize_image(image)

    def distort_image(image):
        noise_amt = tf.abs(tf.random_normal([], stddev=0.2))
        distorted_image = image + tf.random_uniform([192, 160, 3], maxval=noise_amt)
        distorted_image = tf.image.random_flip_left_right(distorted_image)
        distorted_image = tf.image.random_brightness(distorted_image, max_delta=0.3)
        distorted_image = tf.image.random_contrast(distorted_image, lower=0.6, upper=1.6)
        distorted_image = tf.image.per_image_standardization(distorted_image)
        # distorted_image = tf.clip_by_value(distorted_image, 0, 1)
        return distorted_image

    image = distort_image(image) if train else image

    if train:
        images_batch, attrs_batch, rarity_batch = tf.train.shuffle_batch([image, attr_q, rarity_q], batch_size=BATCH_SIZE, capacity=1000, min_after_dequeue=500)
    else:
        images_batch, attrs_batch, rarity_batch = tf.train.batch([image, attr_q, rarity_q], batch_size=BATCH_SIZE, allow_smaller_final_batch=True)
    return images_batch, attrs_batch, rarity_batch

images_batch, attrs_batch, rarity_batch = create_qs(True)
# images_batch_eval, attrs_batch_eval = create_qs(False)

# %%
session = tf.Session()
init_op = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
session.run(init_op)
tf.train.start_queue_runners(sess=session)
# Out:
# [<Thread(Thread-4, started daemon 139659812251392)>,
#  <Thread(Thread-5, started daemon 139659803858688)>]

# %%
# %matplotlib inline

# images_, attrs_, rarity_ = session.run([images_batch, attrs_batch, rarity_batch])

# imshow_multi(images_[:5])

# %%
dropout_keep_prob = tf.placeholder_with_default(tf.constant(1.0), [], name='dropout_keep_prob')        
from tensorflow.contrib.layers.python.layers import batch_norm

keyed_vars = {}
def join_keys(key1, key2):
    if key1 is None or key2 is None:
        return None
    else:
        return key1 + '.' + key2

def weight_var(shape, stddev=0.1, mean=0.0, weight_decay=0, name=None, key=None):
    initial = tf.truncated_normal(shape, mean=mean, stddev=stddev)
    v = tf.Variable(initial, name=name)
    if weight_decay > 0:
        l2 = tf.nn.l2_loss(v) * weight_decay
        tf.add_to_collection('losses', l2)
    if key: keyed_vars[key] = v
    return v

def create_fc(input, out_size, relu=True, key=None):
    # input_dropped = tf.nn.dropout(input, dropout_keep_prob)
    in_size = input.get_shape()[-1].value
    w = weight_var([in_size, out_size], name='w', key=join_keys(key, 'w'))
    b = weight_var([out_size], mean=0.1, name='b', key=join_keys(key, 'b'))
    x = tf.matmul(input, w)
    return tf.nn.relu(x + b) if relu else x + b

def create_conv(input, out_channels, patch_size=5, stride=1, dropout=False, key=None):
    in_channels = input.get_shape()[-1].value
    w = weight_var([patch_size, patch_size, in_channels, out_channels], name='w', key=join_keys(key, 'w'))
    b = weight_var([out_channels], stddev=0, name='b', mean=0.1, key=join_keys(key, 'b'))
    conv = tf.nn.conv2d(input, w, strides=[1,stride,stride,1], padding='SAME')
    activation = tf.nn.relu(conv + b)
    if dropout: activation = create_dropout(activation)
    return activation

def create_max_pool(inputs, ksize=2, stride=2):
    return tf.nn.max_pool(inputs, ksize=[1, ksize, ksize, 1], strides=[1, stride, stride, 1], padding='SAME')

def create_avg_pool(inputs, ksize=2, stride=2):
    return tf.nn.avg_pool(inputs, ksize=[1, ksize, ksize, 1], strides=[1, stride, stride, 1], padding='SAME')

def create_batch_norm(inputs):
    return batch_norm(inputs, is_training=(MODE == 'TRAIN'), updates_collections=None)

def create_dropout(inputs):
    return tf.nn.dropout(inputs, dropout_keep_prob)

def flatten_tensor(t):
    shape = [s.value for s in t.get_shape()]
    flat_size = 1
    for x in shape[1:]:
        flat_size *= x
    return tf.reshape(t, [-1, flat_size])

# %%
def conv_model(image):
    # image size: 192, 160, 3
    conv1 = create_conv(image, 16, patch_size=3, batch_norm=True, key='conv1')
    pool2 = create_max_pool(conv1, ksize=4, stride=4) # [48, 40, 16]
    
    conv3 = create_conv(pool2, 32, patch_size=3, key='conv3')
    pool4 = create_max_pool(conv3) # [24, 40, 32]
    
    conv5 = create_conv(pool4, 32, patch_size=3, batch_norm=True, key='conv5')
    pool6 = create_max_pool(conv5) # [12, 20, 32]
    
    conv7 = create_conv(pool6, 64, patch_size=3, key='conv7')
    pool8 = create_max_pool(conv7) # [6, 10, 64]
    
    conv9 = create_conv(pool8, 32, patch_size=3, key='conv9')
    pool10 = create_max_pool(conv9) # [3, 10, 32]
    
    dropout11 = create_dropout(pool10)
    
    fc12 = create_fc(flatten_tensor(dropout11), 64, key='fc12')
    fc13 = create_fc(fc12, 128, key='fc13')
    return create_fc(fc13, len(keys), relu=False, key='fc14')

def big_conv_model(image):
    # size: 192, 160, 3
    for i, size in enumerate([16, 16, 32, 64, 64]):
        key = 'conv' + str(i)
        image = create_conv(image, size, patch_size=3, batch_norm=True, key=key)
        image = create_avg_pool(image)
    # now we have a 5x64 image:
    image = create_dropout(image)
    image = create_fc(flatten_tensor(image), 256, key='fc1')
    image = create_fc(image, 256, key='fc2')
    return create_fc(image, len(keys), relu=False, key='final')

debug_outputs = []
def facenetwide(image):
    # size: 192, 160, 3
    # 64 -> 32 -> 16 -> 8 -> 4
    image = tf.image.resize_bilinear(image, [64, 64])
    for i, size in enumerate([16, 32, 64, 64]):
        key = 'conv' + str(i)
        image = create_conv(image, size, patch_size=5, key=key)
        # image = create_batch_norm(image)
        debug_outputs.append(image)
        image = create_avg_pool(image)
        debug_outputs.append(image)
    # now we have a 4x4x64 image:
    image = create_dropout(image)
    image = create_fc(flatten_tensor(image), 256, key='fc1')
    debug_outputs.append(image)
    image = create_fc(image, 256, key='fc2')
    debug_outputs.append(image)
    return create_fc(image, len(keys), relu=False, key='fc3')

image_input = tf.placeholder_with_default(images_batch, [None, 192, 160, 3], name='image_input')
actual_attrs = tf.placeholder_with_default(attrs_batch, [None, len(keys)], name='actual_attrs')
rarities = tf.placeholder_with_default(rarity_batch, [None, len(keys)], name='rarities')

attr_logits = facenetwide(image_input)
attr_predictions = tf.sigmoid(attr_logits)

# %%
loss_by_attr = tf.nn.sigmoid_cross_entropy_with_logits(attr_logits, actual_attrs) * rarities
loss = tf.reduce_sum(loss_by_attr)

learn_rate = tf.placeholder_with_default(tf.constant(0.001), [], name='learn_rate')
optimizer = tf.train.AdamOptimizer(learn_rate)
global_step = global_step = tf.contrib.framework.get_or_create_global_step()
train_step = optimizer.minimize(loss, global_step=global_step)

correct_vals = tf.cast(tf.equal(tf.round(actual_attrs), tf.round(attr_predictions)), tf.float32)
# correct_counts = tf.reduce_sum(tf.cast(tf.equal(tf.round(actual_attrs), tf.round(attr_predictions)), tf.float32), axis=0)
scaled_correctness = correct_vals * rarities
scaled_correctness_avg = tf.reduce_mean(scaled_correctness, axis=0) / tf.reduce_mean(rarities, axis=0)

# %%
save_path = 'models/facenet-wide'

init_op = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
session.run(init_op)

saver = None
if save_path:
    if not os.path.exists(save_path):
        os.mkdir(save_path)
    saver = tf.train.Saver()
    ckpt = tf.train.get_checkpoint_state(save_path)
    if ckpt and ckpt.model_checkpoint_path:
        saver.restore(session, ckpt.model_checkpoint_path)
        print 'Restored from checkpoint', ckpt.model_checkpoint_path
    else:
        print 'Did not restore from checkpoint'
else:
    print 'Will not save progress'

if save_path:
    tf.train.write_graph(session.graph_def, save_path, "net.pb", False)
# Out:
# Restored from checkpoint models/facenet-wide/model.ckpt-12500

# %%
if MODE == 'TRAIN':
    feed = {dropout_keep_prob: 0.5}
    prev_losses = []
    rolling_acc_sum = 0
    
    while True:
        step_, loss_, _, acc_ = session.run([global_step, loss, train_step, scaled_correctness_avg], feed_dict=feed)
        rolling_acc_sum += acc_
        prev_losses.append(loss_)
        
        # update learn rate:
        feed[learn_rate] = 0.01
        if step_ > 1000:
            feed[learn_rate] = 0.0001
        # if step_ > 3000:
        #     feed[learn_rate] = 0.0001
        # if step_ > 10000:
        #     feed[learn_rate] = 0.00001
        
        if step_ % 50 == 1:
            avg_loss = sum(prev_losses) / len(prev_losses)
            accuracies = rolling_acc_sum / len(prev_losses)
            prev_losses = []
            rolling_acc_sum = 0
            print 'Step: {}, loss: {}, approx epochs: {}'.format(step_, avg_loss, step_ * BATCH_SIZE / float(len(image_names)))
            if step_ % 100 == 1 and accuracies is not 0:
                print {key: val for key, val in zip(keys, list(accuracies))}
        if step_ % 500 == 0 and saver:
            saver.save(session, save_path + '/model.ckpt', global_step=step_)
            print 'Saved'

# %%
faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def load_image(url):
    file = cStringIO.StringIO(urllib.urlopen(url).read())
    return Image.open(file)

def detect_face(pil_image):
    cvimg = cv2.cvtColor(np.array(pil_image), cv2.COLOR_RGB2BGR)
    gray = cv2.cvtColor(cvimg, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags = cv2.cv.CV_HAAR_SCALE_IMAGE
    )
    faces = list(faces)
    faces.sort(key=lambda(x,y,w,h): w*h, reverse=True)
    if len(faces):
        return faces[0]
    else:
        return None

def crop_to_face(pil_image):
    target_size = (160, 192)
    face = detect_face(pil_image)
    if face is not None:
        center_x = face[0] + face[2] / 2
        center_y = face[1] + face[3] / 2
        width = int(round(face[2] / 0.65))
        height = width * target_size[1] / target_size[0]
        # height = min(pil_image.size[1], height)
        x = center_x - width/2
        y = center_y - height/2
        cropped = pil_image.crop((x, y, x + width, y + height))
        return cropped.resize(target_size, Image.ANTIALIAS)
    else:
        return pil_image

def eval_pic(pil_image):
    img = np.array(crop_to_face(pil_image))
    imshow_multi([img])
    normalized = session.run(tf.image.per_image_standardization(img))
    
    results = session.run(debug_outputs + [attr_predictions], {image_input: np.array([normalized])})
    print 'input image:', normalized[0][0][0:3]
    predictions_= results[-1]
    # predictions_ = session.run(attr_predictions, {image_input: np.array([normalized])})
    for x in results[:-1]:
        if len(x.shape) == 4:
            print x[0][0][0][0]
        elif len(x.shape) == 2:
            print x[0][0]
    
    for key, pred in zip(keys, predictions_[0]):
        print key, round(pred * 10) / 10.0

# %%
# %matplotlib inline

# if MODE == 'EVAL':
#     correct_sum = 0
#     # compute baseline accuracy of a model that just predicts the most likely value for each attribute
#     correct_sum_baseline = 0
#     most_likely = np.round(attr_vector.sum(axis=0, dtype=float) / len(image_names))
#     correct_counts_baseline = tf.reduce_sum(tf.cast(tf.equal(actual_attrs, most_likely), 1.0), axis=0)
    
#     known_total_images = len(image_names)
#     stop_at_count = BATCH_SIZE * 300
#     images_processed = 0
    
#     i = 0
#     while True:
#         correct_, correct_baseline_, preds_ = session.run([correct_counts, correct_counts_baseline, attr_predictions])
#         # print preds_
#         correct_sum += correct_
#         correct_sum_baseline += correct_baseline_
#         images_processed += BATCH_SIZE
#         # this assumes all batches are BATCH_SIZE (the last one might be smaller) but that's okay
#         i += 1
#         if i % 20 == 0:
#             print str(images_processed / float(stop_at_count) * 100) + '% done'
#         if images_processed >= stop_at_count: break
    
#     for key in keys:
#         i = keys.index(key)
#         correct = correct_sum[i]
#         baseline_correct = correct_sum_baseline[i]
#         print key, correct / float(stop_at_count)
#         # print ' baseline:', baseline_correct / float(stop_at_count)
#         # print ''

if MODE == 'EVAL':
    if True:
        meryl_streep = 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4b/Meryl_Streep_February_2016.jpg/220px-Meryl_Streep_February_2016.jpg'
        obama = 'http://viralcypher.com/wp-content/uploads/2016/11/obama.jpg'
        cpax = 'https://news.brown.edu/files/styles/vertical/public/article_images/Paxson72a_3.jpg?itok=aLoYkVWa'
        n8 = 'https://avatars3.githubusercontent.com/u/3059249?v=3&s=460'
        justin = 'https://scontent.fhan4-1.fna.fbcdn.net/v/t1.0-9/15895316_10207891864551393_3694897809127225461_n.jpg?oh=6946c7c4e072126072ce92bce9dfaa9e&oe=58DBF90E'
        beyonce = 'http://factmag-images.s3.amazonaws.com/wp-content/uploads/2013/12/beyonce-121313.jpg'
        michelle = 'https://peopledotcom.files.wordpress.com/2016/08/michelle-obama-1024.jpg'
        
        url = michelle
        eval_pic(load_image(url))
    if False:
        images_, predictions_ = session.run([image_input, attr_predictions])
        for x in range(1):
            img = np.clip(images_[x]/2 + 0.5, 0, 1)
            imshow_multi([img])
            for key, pred in zip(keys, predictions_[x]):
                print key, round(pred * 10) / 10.0
    
    if False:
        correctness_sum = 0
        n_batches = 100

        for i in xrange(n_batches):
            correctness_sum += session.run(scaled_correctness_avg)
            if i % 20 == 0:
                print str(i / float(n_batches) * 100) + '% done'

        for key, score in zip(keys, correctness_sum / n_batches):
            print key, score
# Out:
# input image: [ 0.22865343  0.41427916  0.81646824]
# 0.0
# 0.0
# 0.0
# 0.0
# 0.00510801
# 0.00498405
# 0.12194
# 0.0304849
# 0.0
# 0.0
# 5_o_Clock_Shadow 0.0
# Arched_Eyebrows 0.6
# Attractive 0.7
# Bags_Under_Eyes 0.3
# Bald 0.0
# Bangs 0.4
# Big_Lips 0.6
# Big_Nose 0.3
# Black_Hair 0.6
# Blond_Hair 0.1
# Blurry 0.4
# Brown_Hair 0.6
# Bushy_Eyebrows 0.5
# Chubby 0.2
# Double_Chin 0.1
# Eyeglasses 0.1
# Goatee 0.0
# Gray_Hair 0.0
# Heavy_Makeup 0.8
# High_Cheekbones 0.5
# Male 0.0
# Mouth_Slightly_Open 0.4
# Mustache 0.0
# Narrow_Eyes 0.5
# No_Beard 1.0
# Oval_Face 0.5
# Pale_Skin 0.6
# Pointy_Nose 0.6
# Receding_Hairline 0.1
# Rosy_Cheeks 0.4
# Sideburns 0.0
# Smiling 0.4
# Straight_Hair 0.5
# Wavy_Hair 0.6
# Wearing_Earrings 0.6
# Wearing_Hat 0.1
# Wearing_Lipstick 0.8
# Wearing_Necklace 0.6
# Wearing_Necktie 0.0
# Young 0.7

# %%
out_dir = 'models/facenet-wide-weights'

if out_dir:
    var_keys = keyed_vars.keys()
    var_values = session.run([keyed_vars[k] for k in var_keys])
    import struct

    for key, val in zip(var_keys, var_values):
        name = key + '.' + '_'.join(map(str, val.shape))
        weights = val.astype(np.float32)
        if key.startswith('conv'):
            if len(weights.shape) == 4:
                weights = weights.transpose([3,2,0,1])
        elif key.startswith('fc'):
            weights = weights.transpose()
        
        bytes = weights.tobytes()
        open(out_dir + '/' + name + '.weight', 'w').write(bytes)

# %%
batchnorm_vals = defaultdict(lambda: [None,None,None]) # (mean, variance,beta)

for v in tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES):
    if v.name.startswith('BatchNorm'):
        # print v.name
        params = batchnorm_vals[v.name.split('/')[0]]
        val = session.run(v)
        # print val.shape
        if '/moving_mean' in v.name:
            params[0] = val
        elif '/moving_variance' in v.name:
            params[1] = val
        elif 'beta' in v.name:
            params[2] = val

for key, vals in batchnorm_vals.iteritems():
    data = np.array(vals).astype(np.float32).tobytes()
    # print len(data)
    open(out_dir + '/' + key, 'w').write(data)
# Out:
# w:0
# b:0
# w_1:0
# b_1:0
# w_2:0
# b_2:0
# w_3:0
# b_3:0
# w_4:0
# b_4:0
# w_5:0
# b_5:0
# w_6:0
# b_6:0
# global_step:0
# beta1_power:0
# beta2_power:0
# w/Adam:0
# w/Adam_1:0
# b/Adam:0
# b/Adam_1:0
# w_1/Adam:0
# w_1/Adam_1:0
# b_1/Adam:0
# b_1/Adam_1:0
# w_2/Adam:0
# w_2/Adam_1:0
# b_2/Adam:0
# b_2/Adam_1:0
# w_3/Adam:0
# w_3/Adam_1:0
# b_3/Adam:0
# b_3/Adam_1:0
# w_4/Adam:0
# w_4/Adam_1:0
# b_4/Adam:0
# b_4/Adam_1:0
# w_5/Adam:0
# w_5/Adam_1:0
# b_5/Adam:0
# b_5/Adam_1:0
# w_6/Adam:0
# w_6/Adam_1:0
# b_6/Adam:0
# b_6/Adam_1:0

# %%
for v in batchnorm_vals['BatchNorm'][1]:
    print v
print batchnorm_vals.keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3daf4a573cbd> in <module>()
# ----> 1 for v in batchnorm_vals['BatchNorm'][1]:
#       2     print v
#       3 print batchnorm_vals.keys()
#
# TypeError: 'NoneType' object is not iterable

# %%
[n.name for n in tf.get_default_graph().as_graph_def().node]
# Out:
# [u'Const',
#  u'Const_1',
#  u'Const_2',
#  u'input_producer/Shape',
#  u'input_producer/strided_slice/stack',
#  u'input_producer/strided_slice/stack_1',
#  u'input_producer/strided_slice/stack_2',
#  u'input_producer/strided_slice',
#  u'input_producer/input_producer/range/start',
#  u'input_producer/input_producer/range/delta',
#  u'input_producer/input_producer/range',
#  u'input_producer/input_producer/fraction_of_32_full/RandomShuffle',
#  u'input_producer/input_producer/fraction_of_32_full/fraction_of_32_full',
#  u'input_producer/input_producer/fraction_of_32_full/fraction_of_32_full_EnqueueMany',
#  u'input_producer/input_producer/fraction_of_32_full/fraction_of_32_full_Close',
#  u'input_producer/input_producer/fraction_of_32_full/fraction_of_32_full_Close_1',
#  u'input_producer/input_producer/fraction_of_32_full/fraction_of_32_full_Size',
#  u'input_producer/input_producer/fraction_of_32_full/Cast',
#  u'input_producer/input_producer/fraction_of_32_full/mul/y',
#  u'input_producer/input_producer/fraction_of_32_full/mul',
#  u'queue/input_producer/input_producer/fraction_of_32_full/fraction_of_32_full/input_producer/input_producer/tags',
#  u'queue/input_producer/input_producer/fraction_of_32_full/fraction_of_32_full/input_producer/input_producer',
#  u'input_producer/fraction_of_32_full_Dequeue',
#  u'input_producer/Gather',
#  u'input_producer/Gather_1',
#  u'input_producer/Gather_2',
#  u'ReadFile',
#  u'DecodeJpeg',
#  u'Cast',
#  u'div/y',
#  u'div',
#  u'Reshape/shape',
#  u'Reshape',
#  u'random_crop/size',
#  u'random_crop/Shape',
#  u'random_crop/GreaterEqual',
#  u'random_crop/Const',
#  u'random_crop/All',
#  u'random_crop/Assert/Const',
#  u'random_crop/Assert/Assert/data_0',
#  u'random_crop/Assert/Assert',
#  u'random_crop/control_dependency',
#  u'random_crop/sub',
#  u'random_crop/add/y',
#  u'random_crop/add',
#  u'random_crop/Shape_1',
#  u'random_crop/random_uniform/min',
#  u'random_crop/random_uniform/max',
#  u'random_crop/random_uniform',
#  u'random_crop/mod',
#  u'random_crop',
#  u'random_normal/shape',
#  u'random_normal/mean',
#  u'random_normal/stddev',
#  u'random_normal/RandomStandardNormal',
#  u'random_normal/mul',
#  u'random_normal',
#  u'Abs',
#  u'random_uniform/shape',
#  u'random_uniform/min',
#  u'random_uniform/RandomUniform',
#  u'random_uniform/sub',
#  u'random_uniform/mul',
#  u'random_uniform',
#  u'add',
#  u'random_uniform_1/shape',
#  u'random_uniform_1/min',
#  u'random_uniform_1/max',
#  u'random_uniform_1/RandomUniform',
#  u'random_uniform_1/sub',
#  u'random_uniform_1/mul',
#  u'random_uniform_1',
#  u'pack/0',
#  u'pack/2',
#  u'pack',
#  u'Less/y',
#  u'Less',
#  u'Reverse',
#  u'random_uniform_2/shape',
#  u'random_uniform_2/min',
#  u'random_uniform_2/max',
#  u'random_uniform_2/RandomUniform',
#  u'random_uniform_2/sub',
#  u'random_uniform_2/mul',
#  u'random_uniform_2',
#  u'adjust_brightness/Identity',
#  u'adjust_brightness',
#  u'adjust_brightness/Identity_1',
#  u'random_uniform_3/shape',
#  u'random_uniform_3/min',
#  u'random_uniform_3/max',
#  u'random_uniform_3/RandomUniform',
#  u'random_uniform_3/sub',
#  u'random_uniform_3/mul',
#  u'random_uniform_3',
#  u'adjust_contrast/Identity',
#  u'adjust_contrast',
#  u'adjust_contrast/Identity_1',
#  u'Shape',
#  u'Const_3',
#  u'Prod',
#  u'Const_4',
#  u'Mean',
#  u'Square',
#  u'Const_5',
#  u'Mean_1',
#  u'Square_1',
#  u'sub',
#  u'Relu',
#  u'Sqrt',
#  u'Cast_2',
#  u'Rsqrt',
#  u'Maximum',
#  u'Sub',
#  u'Div',
#  u'shuffle_batch/random_shuffle_queue',
#  u'shuffle_batch/random_shuffle_queue_enqueue',
#  u'shuffle_batch/random_shuffle_queue_Close',
#  u'shuffle_batch/random_shuffle_queue_Close_1',
#  u'shuffle_batch/random_shuffle_queue_Size',
#  u'shuffle_batch/sub/y',
#  u'shuffle_batch/sub',
#  u'shuffle_batch/Maximum/x',
#  u'shuffle_batch/Maximum',
#  u'shuffle_batch/Cast',
#  u'shuffle_batch/mul/y',
#  u'shuffle_batch/mul',
#  u'shuffle_batch/queue/shuffle_batch/fraction_over_500_of_500_full/tags',
#  u'shuffle_batch/queue/shuffle_batch/fraction_over_500_of_500_full',
#  u'shuffle_batch/n',
#  u'shuffle_batch',
#  u'init',
#  u'init_1',
#  u'group_deps',
#  u'Const_6',
#  u'dropout_keep_prob',
#  u'image_input',
#  u'actual_attrs',
#  u'rarities',
#  u'ResizeBilinear/size',
#  u'ResizeBilinear',
#  u'truncated_normal/shape',
#  u'truncated_normal/mean',
#  u'truncated_normal/stddev',
#  u'truncated_normal/TruncatedNormal',
#  u'truncated_normal/mul',
#  u'truncated_normal',
#  u'w',
#  u'w/Assign',
#  u'w/read',
#  u'truncated_normal_1/shape',
#  u'truncated_normal_1/mean',
#  u'truncated_normal_1/stddev',
#  u'truncated_normal_1/TruncatedNormal',
#  u'truncated_normal_1/mul',
#  u'truncated_normal_1',
#  u'b',
#  u'b/Assign',
#  u'b/read',
#  u'Conv2D',
#  u'add_1',
#  u'Relu_1',
#  u'AvgPool',
#  u'truncated_normal_2/shape',
#  u'truncated_normal_2/mean',
#  u'truncated_normal_2/stddev',
#  u'truncated_normal_2/TruncatedNormal',
#  u'truncated_normal_2/mul',
#  u'truncated_normal_2',
#  u'w_1',
#  u'w_1/Assign',
#  u'w_1/read',
#  u'truncated_normal_3/shape',
#  u'truncated_normal_3/mean',
#  u'truncated_normal_3/stddev',
#  u'truncated_normal_3/TruncatedNormal',
#  u'truncated_normal_3/mul',
#  u'truncated_normal_3',
#  u'b_1',
#  u'b_1/Assign',
#  u'b_1/read',
#  u'Conv2D_1',
#  u'add_2',
#  u'Relu_2',
#  u'AvgPool_1',
#  u'truncated_normal_4/shape',
#  u'truncated_normal_4/mean',
#  u'truncated_normal_4/stddev',
#  u'truncated_normal_4/TruncatedNormal',
#  u'truncated_normal_4/mul',
#  u'truncated_normal_4',
#  u'w_2',
#  u'w_2/Assign',
#  u'w_2/read',
#  u'truncated_normal_5/shape',
#  u'truncated_normal_5/mean',
#  u'truncated_normal_5/stddev',
#  u'truncated_normal_5/TruncatedNormal',
#  u'truncated_normal_5/mul',
#  u'truncated_normal_5',
#  u'b_2',
#  u'b_2/Assign',
#  u'b_2/read',
#  u'Conv2D_2',
#  u'add_3',
#  u'Relu_3',
#  u'AvgPool_2',
#  u'truncated_normal_6/shape',
#  u'truncated_normal_6/mean',
#  u'truncated_normal_6/stddev',
#  u'truncated_normal_6/TruncatedNormal',
#  u'truncated_normal_6/mul',
#  u'truncated_normal_6',
#  u'w_3',
#  u'w_3/Assign',
#  u'w_3/read',
#  u'truncated_normal_7/shape',
#  u'truncated_normal_7/mean',
#  u'truncated_normal_7/stddev',
#  u'truncated_normal_7/TruncatedNormal',
#  u'truncated_normal_7/mul',
#  u'truncated_normal_7',
#  u'b_3',
#  u'b_3/Assign',
#  u'b_3/read',
#  u'Conv2D_3',
#  u'add_4',
#  u'Relu_4',
#  u'AvgPool_3',
#  u'dropout/Shape',
#  u'dropout/random_uniform/min',
#  u'dropout/random_uniform/max',
#  u'dropout/random_uniform/RandomUniform',
#  u'dropout/random_uniform/sub',
#  u'dropout/random_uniform/mul',
#  u'dropout/random_uniform',
#  u'dropout/add',
#  u'dropout/Floor',
#  u'dropout/Div',
#  u'dropout/mul',
#  u'Reshape_1/shape',
#  u'Reshape_1',
#  u'truncated_normal_8/shape',
#  u'truncated_normal_8/mean',
#  u'truncated_normal_8/stddev',
#  u'truncated_normal_8/TruncatedNormal',
#  u'truncated_normal_8/mul',
#  u'truncated_normal_8',
#  u'w_4',
#  u'w_4/Assign',
#  u'w_4/read',
#  u'truncated_normal_9/shape',
#  u'truncated_normal_9/mean',
#  u'truncated_normal_9/stddev',
#  u'truncated_normal_9/TruncatedNormal',
#  u'truncated_normal_9/mul',
#  u'truncated_normal_9',
#  u'b_4',
#  u'b_4/Assign',
#  u'b_4/read',
#  u'MatMul',
#  u'add_5',
#  u'Relu_5',
#  u'truncated_normal_10/shape',
#  u'truncated_normal_10/mean',
#  u'truncated_normal_10/stddev',
#  u'truncated_normal_10/TruncatedNormal',
#  u'truncated_normal_10/mul',
#  u'truncated_normal_10',
#  u'w_5',
#  u'w_5/Assign',
#  u'w_5/read',
#  u'truncated_normal_11/shape',
#  u'truncated_normal_11/mean',
#  u'truncated_normal_11/stddev',
#  u'truncated_normal_11/TruncatedNormal',
#  u'truncated_normal_11/mul',
#  u'truncated_normal_11',
#  u'b_5',
#  u'b_5/Assign',
#  u'b_5/read',
#  u'MatMul_1',
#  u'add_6',
#  u'Relu_6',
#  u'truncated_normal_12/shape',
#  u'truncated_normal_12/mean',
#  u'truncated_normal_12/stddev',
#  u'truncated_normal_12/TruncatedNormal',
#  u'truncated_normal_12/mul',
#  u'truncated_normal_12',
#  u'w_6',
#  u'w_6/Assign',
#  u'w_6/read',
#  u'truncated_normal_13/shape',
#  u'truncated_normal_13/mean',
#  u'truncated_normal_13/stddev',
#  u'truncated_normal_13/TruncatedNormal',
#  u'truncated_normal_13/mul',
#  u'truncated_normal_13',
#  u'b_6',
#  u'b_6/Assign',
#  u'b_6/read',
#  u'MatMul_2',
#  u'add_7',
#  u'Sigmoid',
#  u'logistic_loss/zeros_like',
#  u'logistic_loss/GreaterEqual',
#  u'logistic_loss/Select',
#  u'logistic_loss/Neg',
#  u'logistic_loss/Select_1',
#  u'logistic_loss/mul',
#  u'logistic_loss/sub',
#  u'logistic_loss/Exp',
#  u'logistic_loss/Log1p',
#  u'logistic_loss',
#  u'mul',
#  u'Const_7',
#  u'Sum',
#  u'Const_8',
#  u'learn_rate',
#  u'global_step',
#  u'global_step/Initializer/zeros',
#  u'global_step/Assign',
#  u'global_step/read',
#  u'gradients/Shape',
#  u'gradients/Const',
#  u'gradients/Fill',
#  u'gradients/Sum_grad/Reshape/shape',
#  u'gradients/Sum_grad/Reshape',
#  u'gradients/Sum_grad/Shape',
#  u'gradients/Sum_grad/Tile',
#  u'gradients/mul_grad/Shape',
#  u'gradients/mul_grad/Shape_1',
#  u'gradients/mul_grad/BroadcastGradientArgs',
#  u'gradients/mul_grad/mul',
#  u'gradients/mul_grad/Sum',
#  u'gradients/mul_grad/Reshape',
#  u'gradients/mul_grad/mul_1',
#  u'gradients/mul_grad/Sum_1',
#  u'gradients/mul_grad/Reshape_1',
#  u'gradients/mul_grad/tuple/group_deps',
#  u'gradients/mul_grad/tuple/control_dependency',
#  u'gradients/mul_grad/tuple/control_dependency_1',
#  u'gradients/logistic_loss_grad/Shape',
#  u'gradients/logistic_loss_grad/Shape_1',
#  u'gradients/logistic_loss_grad/BroadcastGradientArgs',
#  u'gradients/logistic_loss_grad/Sum',
#  u'gradients/logistic_loss_grad/Reshape',
#  u'gradients/logistic_loss_grad/Sum_1',
#  u'gradients/logistic_loss_grad/Reshape_1',
#  u'gradients/logistic_loss_grad/tuple/group_deps',
#  u'gradients/logistic_loss_grad/tuple/control_dependency',
#  u'gradients/logistic_loss_grad/tuple/control_dependency_1',
#  u'gradients/logistic_loss/sub_grad/Shape',
#  u'gradients/logistic_loss/sub_grad/Shape_1',
#  u'gradients/logistic_loss/sub_grad/BroadcastGradientArgs',
#  u'gradients/logistic_loss/sub_grad/Sum',
#  u'gradients/logistic_loss/sub_grad/Reshape',
#  u'gradients/logistic_loss/sub_grad/Sum_1',
#  u'gradients/logistic_loss/sub_grad/Neg',
#  u'gradients/logistic_loss/sub_grad/Reshape_1',
#  u'gradients/logistic_loss/sub_grad/tuple/group_deps',
#  u'gradients/logistic_loss/sub_grad/tuple/control_dependency',
#  u'gradients/logistic_loss/sub_grad/tuple/control_dependency_1',
#  u'gradients/logistic_loss/Log1p_grad/add/x',
#  u'gradients/logistic_loss/Log1p_grad/add',
#  u'gradients/logistic_loss/Log1p_grad/Reciprocal',
#  u'gradients/logistic_loss/Log1p_grad/mul',
#  u'gradients/logistic_loss/Select_grad/zeros_like',
#  u'gradients/logistic_loss/Select_grad/Select',
#  u'gradients/logistic_loss/Select_grad/Select_1',
#  u'gradients/logistic_loss/Select_grad/tuple/group_deps',
#  u'gradients/logistic_loss/Select_grad/tuple/control_dependency',
#  u'gradients/logistic_loss/Select_grad/tuple/control_dependency_1',
#  u'gradients/logistic_loss/mul_grad/Shape',
#  u'gradients/logistic_loss/mul_grad/Shape_1',
#  u'gradients/logistic_loss/mul_grad/BroadcastGradientArgs',
#  u'gradients/logistic_loss/mul_grad/mul',
#  u'gradients/logistic_loss/mul_grad/Sum',
#  u'gradients/logistic_loss/mul_grad/Reshape',
#  u'gradients/logistic_loss/mul_grad/mul_1',
#  u'gradients/logistic_loss/mul_grad/Sum_1',
#  u'gradients/logistic_loss/mul_grad/Reshape_1',
#  u'gradients/logistic_loss/mul_grad/tuple/group_deps',
#  u'gradients/logistic_loss/mul_grad/tuple/control_dependency',
#  u'gradients/logistic_loss/mul_grad/tuple/control_dependency_1',
#  u'gradients/logistic_loss/Exp_grad/mul',
#  u'gradients/logistic_loss/Select_1_grad/zeros_like',
#  u'gradients/logistic_loss/Select_1_grad/Select',
#  u'gradients/logistic_loss/Select_1_grad/Select_1',
#  u'gradients/logistic_loss/Select_1_grad/tuple/group_deps',
#  u'gradients/logistic_loss/Select_1_grad/tuple/control_dependency',
#  u'gradients/logistic_loss/Select_1_grad/tuple/control_dependency_1',
#  u'gradients/logistic_loss/Neg_grad/Neg',
#  u'gradients/AddN',
#  u'gradients/add_7_grad/Shape',
#  u'gradients/add_7_grad/Shape_1',
#  u'gradients/add_7_grad/BroadcastGradientArgs',
#  u'gradients/add_7_grad/Sum',
#  u'gradients/add_7_grad/Reshape',
#  u'gradients/add_7_grad/Sum_1',
#  u'gradients/add_7_grad/Reshape_1',
#  u'gradients/add_7_grad/tuple/group_deps',
#  u'gradients/add_7_grad/tuple/control_dependency',
#  u'gradients/add_7_grad/tuple/control_dependency_1',
#  u'gradients/MatMul_2_grad/MatMul',
#  u'gradients/MatMul_2_grad/MatMul_1',
#  u'gradients/MatMul_2_grad/tuple/group_deps',
#  u'gradients/MatMul_2_grad/tuple/control_dependency',
#  u'gradients/MatMul_2_grad/tuple/control_dependency_1',
#  u'gradients/Relu_6_grad/ReluGrad',
#  u'gradients/add_6_grad/Shape',
#  u'gradients/add_6_grad/Shape_1',
#  u'gradients/add_6_grad/BroadcastGradientArgs',
#  u'gradients/add_6_grad/Sum',
#  u'gradients/add_6_grad/Reshape',
#  u'gradients/add_6_grad/Sum_1',
#  u'gradients/add_6_grad/Reshape_1',
#  u'gradients/add_6_grad/tuple/group_deps',
#  u'gradients/add_6_grad/tuple/control_dependency',
#  u'gradients/add_6_grad/tuple/control_dependency_1',
#  u'gradients/MatMul_1_grad/MatMul',
#  u'gradients/MatMul_1_grad/MatMul_1',
#  u'gradients/MatMul_1_grad/tuple/group_deps',
#  u'gradients/MatMul_1_grad/tuple/control_dependency',
#  u'gradients/MatMul_1_grad/tuple/control_dependency_1',
#  u'gradients/Relu_5_grad/ReluGrad',
#  u'gradients/add_5_grad/Shape',
#  u'gradients/add_5_grad/Shape_1',
#  u'gradients/add_5_grad/BroadcastGradientArgs',
#  u'gradients/add_5_grad/Sum',
#  u'gradients/add_5_grad/Reshape',
#  u'gradients/add_5_grad/Sum_1',
#  u'gradients/add_5_grad/Reshape_1',
#  u'gradients/add_5_grad/tuple/group_deps',
#  u'gradients/add_5_grad/tuple/control_dependency',
#  u'gradients/add_5_grad/tuple/control_dependency_1',
#  u'gradients/MatMul_grad/MatMul',
#  u'gradients/MatMul_grad/MatMul_1',
#  u'gradients/MatMul_grad/tuple/group_deps',
#  u'gradients/MatMul_grad/tuple/control_dependency',
#  u'gradients/MatMul_grad/tuple/control_dependency_1',
#  u'gradients/Reshape_1_grad/Shape',
#  u'gradients/Reshape_1_grad/Reshape',
#  u'gradients/dropout/mul_grad/Shape',
#  u'gradients/dropout/mul_grad/Shape_1',
#  u'gradients/dropout/mul_grad/BroadcastGradientArgs',
#  u'gradients/dropout/mul_grad/mul',
#  u'gradients/dropout/mul_grad/Sum',
#  u'gradients/dropout/mul_grad/Reshape',
#  u'gradients/dropout/mul_grad/mul_1',
#  u'gradients/dropout/mul_grad/Sum_1',
#  u'gradients/dropout/mul_grad/Reshape_1',
#  u'gradients/dropout/mul_grad/tuple/group_deps',
#  u'gradients/dropout/mul_grad/tuple/control_dependency',
#  u'gradients/dropout/mul_grad/tuple/control_dependency_1',
#  u'gradients/dropout/Div_grad/Shape',
#  u'gradients/dropout/Div_grad/Shape_1',
#  u'gradients/dropout/Div_grad/BroadcastGradientArgs',
#  u'gradients/dropout/Div_grad/truediv',
#  u'gradients/dropout/Div_grad/Sum',
#  u'gradients/dropout/Div_grad/Reshape',
#  u'gradients/dropout/Div_grad/Neg',
#  u'gradients/dropout/Div_grad/Square',
#  u'gradients/dropout/Div_grad/truediv_1',
#  u'gradients/dropout/Div_grad/mul',
#  u'gradients/dropout/Div_grad/Sum_1',
#  u'gradients/dropout/Div_grad/Reshape_1',
#  u'gradients/dropout/Div_grad/tuple/group_deps',
#  u'gradients/dropout/Div_grad/tuple/control_dependency',
#  u'gradients/dropout/Div_grad/tuple/control_dependency_1',
#  u'gradients/AvgPool_3_grad/Shape',
#  u'gradients/AvgPool_3_grad/AvgPoolGrad',
#  u'gradients/Relu_4_grad/ReluGrad',
#  u'gradients/add_4_grad/Shape',
#  u'gradients/add_4_grad/Shape_1',
#  u'gradients/add_4_grad/BroadcastGradientArgs',
#  u'gradients/add_4_grad/Sum',
#  u'gradients/add_4_grad/Reshape',
#  u'gradients/add_4_grad/Sum_1',
#  u'gradients/add_4_grad/Reshape_1',
#  u'gradients/add_4_grad/tuple/group_deps',
#  u'gradients/add_4_grad/tuple/control_dependency',
#  u'gradients/add_4_grad/tuple/control_dependency_1',
#  u'gradients/Conv2D_3_grad/Shape',
#  u'gradients/Conv2D_3_grad/Conv2DBackpropInput',
#  u'gradients/Conv2D_3_grad/Shape_1',
#  u'gradients/Conv2D_3_grad/Conv2DBackpropFilter',
#  u'gradients/Conv2D_3_grad/tuple/group_deps',
#  u'gradients/Conv2D_3_grad/tuple/control_dependency',
#  u'gradients/Conv2D_3_grad/tuple/control_dependency_1',
#  u'gradients/AvgPool_2_grad/Shape',
#  u'gradients/AvgPool_2_grad/AvgPoolGrad',
#  u'gradients/Relu_3_grad/ReluGrad',
#  u'gradients/add_3_grad/Shape',
#  u'gradients/add_3_grad/Shape_1',
#  u'gradients/add_3_grad/BroadcastGradientArgs',
#  u'gradients/add_3_grad/Sum',
#  u'gradients/add_3_grad/Reshape',
#  u'gradients/add_3_grad/Sum_1',
#  u'gradients/add_3_grad/Reshape_1',
#  u'gradients/add_3_grad/tuple/group_deps',
#  u'gradients/add_3_grad/tuple/control_dependency',
#  u'gradients/add_3_grad/tuple/control_dependency_1',
#  u'gradients/Conv2D_2_grad/Shape',
#  u'gradients/Conv2D_2_grad/Conv2DBackpropInput',
#  u'gradients/Conv2D_2_grad/Shape_1',
#  u'gradients/Conv2D_2_grad/Conv2DBackpropFilter',
#  u'gradients/Conv2D_2_grad/tuple/group_deps',
#  u'gradients/Conv2D_2_grad/tuple/control_dependency',
#  u'gradients/Conv2D_2_grad/tuple/control_dependency_1',
#  u'gradients/AvgPool_1_grad/Shape',
#  u'gradients/AvgPool_1_grad/AvgPoolGrad',
#  u'gradients/Relu_2_grad/ReluGrad',
#  u'gradients/add_2_grad/Shape',
#  u'gradients/add_2_grad/Shape_1',
#  u'gradients/add_2_grad/BroadcastGradientArgs',
#  u'gradients/add_2_grad/Sum',
#  u'gradients/add_2_grad/Reshape',
#  u'gradients/add_2_grad/Sum_1',
#  u'gradients/add_2_grad/Reshape_1',
#  u'gradients/add_2_grad/tuple/group_deps',
#  u'gradients/add_2_grad/tuple/control_dependency',
#  u'gradients/add_2_grad/tuple/control_dependency_1',
#  u'gradients/Conv2D_1_grad/Shape',
#  u'gradients/Conv2D_1_grad/Conv2DBackpropInput',
#  u'gradients/Conv2D_1_grad/Shape_1',
#  u'gradients/Conv2D_1_grad/Conv2DBackpropFilter',
#  u'gradients/Conv2D_1_grad/tuple/group_deps',
#  u'gradients/Conv2D_1_grad/tuple/control_dependency',
#  u'gradients/Conv2D_1_grad/tuple/control_dependency_1',
#  u'gradients/AvgPool_grad/Shape',
#  u'gradients/AvgPool_grad/AvgPoolGrad',
#  u'gradients/Relu_1_grad/ReluGrad',
#  u'gradients/add_1_grad/Shape',
#  u'gradients/add_1_grad/Shape_1',
#  u'gradients/add_1_grad/BroadcastGradientArgs',
#  u'gradients/add_1_grad/Sum',
#  u'gradients/add_1_grad/Reshape',
#  u'gradients/add_1_grad/Sum_1',
#  u'gradients/add_1_grad/Reshape_1',
#  u'gradients/add_1_grad/tuple/group_deps',
#  u'gradients/add_1_grad/tuple/control_dependency',
#  u'gradients/add_1_grad/tuple/control_dependency_1',
#  u'gradients/Conv2D_grad/Shape',
#  u'gradients/Conv2D_grad/Conv2DBackpropInput',
#  u'gradients/Conv2D_grad/Shape_1',
#  u'gradients/Conv2D_grad/Conv2DBackpropFilter',
#  u'gradients/Conv2D_grad/tuple/group_deps',
#  u'gradients/Conv2D_grad/tuple/control_dependency',
#  u'gradients/Conv2D_grad/tuple/control_dependency_1',
#  u'beta1_power/initial_value',
#  u'beta1_power',
#  u'beta1_power/Assign',
#  u'beta1_power/read',
#  u'beta2_power/initial_value',
#  u'beta2_power',
#  u'beta2_power/Assign',
#  u'beta2_power/read',
#  u'zeros',
#  u'w/Adam',
#  u'w/Adam/Assign',
#  u'w/Adam/read',
#  u'zeros_1',
#  u'w/Adam_1',
#  u'w/Adam_1/Assign',
#  u'w/Adam_1/read',
#  u'zeros_2',
#  u'b/Adam',
#  u'b/Adam/Assign',
#  u'b/Adam/read',
#  u'zeros_3',
#  u'b/Adam_1',
#  u'b/Adam_1/Assign',
#  u'b/Adam_1/read',
#  u'zeros_4',
#  u'w_1/Adam',
#  u'w_1/Adam/Assign',
#  u'w_1/Adam/read',
#  u'zeros_5',
#  u'w_1/Adam_1',
#  u'w_1/Adam_1/Assign',
#  u'w_1/Adam_1/read',
#  u'zeros_6',
#  u'b_1/Adam',
#  u'b_1/Adam/Assign',
#  u'b_1/Adam/read',
#  u'zeros_7',
#  u'b_1/Adam_1',
#  u'b_1/Adam_1/Assign',
#  u'b_1/Adam_1/read',
#  u'zeros_8',
#  u'w_2/Adam',
#  u'w_2/Adam/Assign',
#  u'w_2/Adam/read',
#  u'zeros_9',
#  u'w_2/Adam_1',
#  u'w_2/Adam_1/Assign',
#  u'w_2/Adam_1/read',
#  u'zeros_10',
#  u'b_2/Adam',
#  u'b_2/Adam/Assign',
#  u'b_2/Adam/read',
#  u'zeros_11',
#  u'b_2/Adam_1',
#  u'b_2/Adam_1/Assign',
#  u'b_2/Adam_1/read',
#  u'zeros_12',
#  u'w_3/Adam',
#  u'w_3/Adam/Assign',
#  u'w_3/Adam/read',
#  u'zeros_13',
#  u'w_3/Adam_1',
#  u'w_3/Adam_1/Assign',
#  u'w_3/Adam_1/read',
#  u'zeros_14',
#  u'b_3/Adam',
#  u'b_3/Adam/Assign',
#  u'b_3/Adam/read',
#  u'zeros_15',
#  u'b_3/Adam_1',
#  u'b_3/Adam_1/Assign',
#  u'b_3/Adam_1/read',
#  u'zeros_16',
#  u'w_4/Adam',
#  u'w_4/Adam/Assign',
#  u'w_4/Adam/read',
#  u'zeros_17',
#  u'w_4/Adam_1',
#  u'w_4/Adam_1/Assign',
#  u'w_4/Adam_1/read',
#  u'zeros_18',
#  u'b_4/Adam',
#  u'b_4/Adam/Assign',
#  u'b_4/Adam/read',
#  u'zeros_19',
#  u'b_4/Adam_1',
#  u'b_4/Adam_1/Assign',
#  u'b_4/Adam_1/read',
#  u'zeros_20',
#  u'w_5/Adam',
#  u'w_5/Adam/Assign',
#  u'w_5/Adam/read',
#  u'zeros_21',
#  u'w_5/Adam_1',
#  u'w_5/Adam_1/Assign',
#  u'w_5/Adam_1/read',
#  u'zeros_22',
#  u'b_5/Adam',
#  u'b_5/Adam/Assign',
#  u'b_5/Adam/read',
#  u'zeros_23',
#  u'b_5/Adam_1',
#  u'b_5/Adam_1/Assign',
#  u'b_5/Adam_1/read',
#  u'zeros_24',
#  u'w_6/Adam',
#  u'w_6/Adam/Assign',
#  u'w_6/Adam/read',
#  u'zeros_25',
#  u'w_6/Adam_1',
#  u'w_6/Adam_1/Assign',
#  u'w_6/Adam_1/read',
#  u'zeros_26',
#  u'b_6/Adam',
#  u'b_6/Adam/Assign',
#  u'b_6/Adam/read',
#  u'zeros_27',
#  u'b_6/Adam_1',
#  u'b_6/Adam_1/Assign',
#  u'b_6/Adam_1/read',
#  u'Adam/beta1',
#  u'Adam/beta2',
#  u'Adam/epsilon',
#  u'Adam/update_w/ApplyAdam',
#  u'Adam/update_b/ApplyAdam',
#  u'Adam/update_w_1/ApplyAdam',
#  u'Adam/update_b_1/ApplyAdam',
#  u'Adam/update_w_2/ApplyAdam',
#  u'Adam/update_b_2/ApplyAdam',
#  u'Adam/update_w_3/ApplyAdam',
#  u'Adam/update_b_3/ApplyAdam',
#  u'Adam/update_w_4/ApplyAdam',
#  u'Adam/update_b_4/ApplyAdam',
#  u'Adam/update_w_5/ApplyAdam',
#  u'Adam/update_b_5/ApplyAdam',
#  u'Adam/update_w_6/ApplyAdam',
#  u'Adam/update_b_6/ApplyAdam',
#  u'Adam/mul',
#  u'Adam/Assign',
#  u'Adam/mul_1',
#  u'Adam/Assign_1',
#  u'Adam/update',
#  u'Adam/value',
#  u'Adam',
#  u'Round',
#  u'Round_1',
#  u'Equal',
#  u'Cast_3',
#  u'mul_1',
#  u'Mean_2/reduction_indices',
#  u'Mean_2',
#  u'Mean_3/reduction_indices',
#  u'Mean_3',
#  u'div_1',
#  u'init_2',
#  u'init_3',
#  u'group_deps_1',
#  u'save/Const',
#  u'save/SaveV2/tensor_names',
#  u'save/SaveV2/shape_and_slices',
#  u'save/SaveV2',
#  u'save/control_dependency',
#  u'save/RestoreV2/tensor_names',
#  u'save/RestoreV2/shape_and_slices',
#  u'save/RestoreV2',
#  u'save/Assign',
#  u'save/RestoreV2_1/tensor_names',
#  u'save/RestoreV2_1/shape_and_slices',
#  u'save/RestoreV2_1',
#  u'save/Assign_1',
#  u'save/RestoreV2_2/tensor_names',
#  u'save/RestoreV2_2/shape_and_slices',
#  u'save/RestoreV2_2',
#  u'save/Assign_2',
#  u'save/RestoreV2_3/tensor_names',
#  u'save/RestoreV2_3/shape_and_slices',
#  u'save/RestoreV2_3',
#  u'save/Assign_3',
#  u'save/RestoreV2_4/tensor_names',
#  u'save/RestoreV2_4/shape_and_slices',
#  u'save/RestoreV2_4',
#  u'save/Assign_4',
#  u'save/RestoreV2_5/tensor_names',
#  u'save/RestoreV2_5/shape_and_slices',
#  u'save/RestoreV2_5',
#  u'save/Assign_5',
#  u'save/RestoreV2_6/tensor_names',
#  u'save/RestoreV2_6/shape_and_slices',
#  u'save/RestoreV2_6',
#  u'save/Assign_6',
#  u'save/RestoreV2_7/tensor_names',
#  u'save/RestoreV2_7/shape_and_slices',
#  u'save/RestoreV2_7',
#  u'save/Assign_7',
#  u'save/RestoreV2_8/tensor_names',
#  u'save/RestoreV2_8/shape_and_slices',
#  u'save/RestoreV2_8',
#  u'save/Assign_8',
#  u'save/RestoreV2_9/tensor_names',
#  u'save/RestoreV2_9/shape_and_slices',
#  u'save/RestoreV2_9',
#  u'save/Assign_9',
#  u'save/RestoreV2_10/tensor_names',
#  u'save/RestoreV2_10/shape_and_slices',
#  u'save/RestoreV2_10',
#  u'save/Assign_10',
#  u'save/RestoreV2_11/tensor_names',
#  u'save/RestoreV2_11/shape_and_slices',
#  u'save/RestoreV2_11',
#  u'save/Assign_11',
#  u'save/RestoreV2_12/tensor_names',
#  u'save/RestoreV2_12/shape_and_slices',
#  u'save/RestoreV2_12',
#  u'save/Assign_12',
#  u'save/RestoreV2_13/tensor_names',
#  u'save/RestoreV2_13/shape_and_slices',
#  u'save/RestoreV2_13',
#  u'save/Assign_13',
#  u'save/RestoreV2_14/tensor_names',
#  u'save/RestoreV2_14/shape_and_slices',
#  u'save/RestoreV2_14',
#  u'save/Assign_14',
#  u'save/RestoreV2_15/tensor_names',
#  u'save/RestoreV2_15/shape_and_slices',
#  u'save/RestoreV2_15',
#  u'save/Assign_15',
#  u'save/RestoreV2_16/tensor_names',
#  u'save/RestoreV2_16/shape_and_slices',
#  u'save/RestoreV2_16',
#  u'save/Assign_16',
#  u'save/RestoreV2_17/tensor_names',
#  u'save/RestoreV2_17/shape_and_slices',
#  u'save/RestoreV2_17',
#  u'save/Assign_17',
#  u'save/RestoreV2_18/tensor_names',
#  u'save/RestoreV2_18/shape_and_slices',
#  u'save/RestoreV2_18',
#  u'save/Assign_18',
#  u'save/RestoreV2_19/tensor_names',
#  u'save/RestoreV2_19/shape_and_slices',
#  u'save/RestoreV2_19',
#  u'save/Assign_19',
#  u'save/RestoreV2_20/tensor_names',
#  u'save/RestoreV2_20/shape_and_slices',
#  u'save/RestoreV2_20',
#  u'save/Assign_20',
#  u'save/RestoreV2_21/tensor_names',
#  u'save/RestoreV2_21/shape_and_slices',
#  u'save/RestoreV2_21',
#  u'save/Assign_21',
#  u'save/RestoreV2_22/tensor_names',
#  u'save/RestoreV2_22/shape_and_slices',
#  u'save/RestoreV2_22',
#  u'save/Assign_22',
#  u'save/RestoreV2_23/tensor_names',
#  u'save/RestoreV2_23/shape_and_slices',
#  u'save/RestoreV2_23',
#  u'save/Assign_23',
#  u'save/RestoreV2_24/tensor_names',
#  u'save/RestoreV2_24/shape_and_slices',
#  u'save/RestoreV2_24',
#  u'save/Assign_24',
#  u'save/RestoreV2_25/tensor_names',
#  u'save/RestoreV2_25/shape_and_slices',
#  u'save/RestoreV2_25',
#  u'save/Assign_25',
#  u'save/RestoreV2_26/tensor_names',
#  u'save/RestoreV2_26/shape_and_slices',
#  u'save/RestoreV2_26',
#  u'save/Assign_26',
#  u'save/RestoreV2_27/tensor_names',
#  u'save/RestoreV2_27/shape_and_slices',
#  u'save/RestoreV2_27',
#  u'save/Assign_27',
#  u'save/RestoreV2_28/tensor_names',
#  u'save/RestoreV2_28/shape_and_slices',
#  u'save/RestoreV2_28',
#  u'save/Assign_28',
#  u'save/RestoreV2_29/tensor_names',
#  u'save/RestoreV2_29/shape_and_slices',
#  u'save/RestoreV2_29',
#  u'save/Assign_29',
#  u'save/RestoreV2_30/tensor_names',
#  u'save/RestoreV2_30/shape_and_slices',
#  u'save/RestoreV2_30',
#  u'save/Assign_30',
#  u'save/RestoreV2_31/tensor_names',
#  u'save/RestoreV2_31/shape_and_slices',
#  u'save/RestoreV2_31',
#  u'save/Assign_31',
#  u'save/RestoreV2_32/tensor_names',
#  u'save/RestoreV2_32/shape_and_slices',
#  u'save/RestoreV2_32',
#  u'save/Assign_32',
#  u'save/RestoreV2_33/tensor_names',
#  u'save/RestoreV2_33/shape_and_slices',
#  u'save/RestoreV2_33',
#  u'save/Assign_33',
#  u'save/RestoreV2_34/tensor_names',
#  u'save/RestoreV2_34/shape_and_slices',
#  u'save/RestoreV2_34',
#  u'save/Assign_34',
#  u'save/RestoreV2_35/tensor_names',
#  u'save/RestoreV2_35/shape_and_slices',
#  u'save/RestoreV2_35',
#  u'save/Assign_35',
#  u'save/RestoreV2_36/tensor_names',
#  u'save/RestoreV2_36/shape_and_slices',
#  u'save/RestoreV2_36',
#  u'save/Assign_36',
#  u'save/RestoreV2_37/tensor_names',
#  u'save/RestoreV2_37/shape_and_slices',
#  u'save/RestoreV2_37',
#  u'save/Assign_37',
#  u'save/RestoreV2_38/tensor_names',
#  u'save/RestoreV2_38/shape_and_slices',
#  u'save/RestoreV2_38',
#  u'save/Assign_38',
#  u'save/RestoreV2_39/tensor_names',
#  u'save/RestoreV2_39/shape_and_slices',
#  u'save/RestoreV2_39',
#  u'save/Assign_39',
#  u'save/RestoreV2_40/tensor_names',
#  u'save/RestoreV2_40/shape_and_slices',
#  u'save/RestoreV2_40',
#  u'save/Assign_40',
#  u'save/RestoreV2_41/tensor_names',
#  u'save/RestoreV2_41/shape_and_slices',
#  u'save/RestoreV2_41',
#  u'save/Assign_41',
#  u'save/RestoreV2_42/tensor_names',
#  u'save/RestoreV2_42/shape_and_slices',
#  u'save/RestoreV2_42',
#  u'save/Assign_42',
#  u'save/RestoreV2_43/tensor_names',
#  u'save/RestoreV2_43/shape_and_slices',
#  u'save/RestoreV2_43',
#  u'save/Assign_43',
#  u'save/RestoreV2_44/tensor_names',
#  u'save/RestoreV2_44/shape_and_slices',
#  u'save/RestoreV2_44',
#  u'save/Assign_44',
#  u'save/restore_all',
#  u'image',
#  u'Shape_1',
#  u'Const_9',
#  u'Prod_1',
#  u'Cast_4',
#  u'Const_10',
#  u'Mean_4',
#  u'Square_2',
#  u'Const_11',
#  u'Mean_5',
#  u'Square_3',
#  u'sub_1',
#  u'Relu_7',
#  u'Sqrt_1',
#  u'Cast_5',
#  u'Rsqrt_1',
#  u'Maximum_1',
#  u'Sub_1',
#  u'Div_1']
