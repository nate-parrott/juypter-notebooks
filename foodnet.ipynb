# %%
import numpy as np
import tensorflow as tf

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-40582ccbe6c4> in <module>()
# ----> 1 from datasets import dataset_utils
#
# ImportError: No module named datasets
